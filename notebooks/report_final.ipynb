# %% [markdown]
# # 最終レポート(提出期限6/4)
#
# **必ず名前と学籍番号を書くこと**
#
# 名前：
#
# 学籍番号：
#
# ## 1 顧客クラスタリングと解釈(10点)
#
# 顧客データをもとに、クラスタリングを行い、クラスタ数を変えてクラスタがどう変化するかを確認せよ(5点)。クラスタ毎に、どのような集団であるかの説明を試みよ(5点)。

# %% [markdown]
# ## 2 データ分析のプロセス(記述問題、20点)
#
# 第１回講義「データ分析のプロセスの例」(P12)に従い、
#
# 1. 仮想的なプロジェクト、あるいは、講義で紹介した事例やレポート課題を参考に、1～7に相当する具体的な活動をそれぞれ書き出せ（２～３行程度）(14点)
# 2. 1で作成した仮想的なデータ分析のシナリオに対して、予想しうる、課題や、問題点を３つ列挙せよ(6点)

# %% [markdown]
# #### 解答欄2-1
#
# 1. ビジネスの理解<br>
#    （ここに記述）
# 2. データの理解<br>
#    (ここに記述）
# 3. データの準備<br>
#    (ここに記述）
# 4. モデル作成<br>
#    (ここに記述）
# 5. 評価<br>
#    (ここに記述）
# 6. 展開<br>
#    (ここに記述）
# 7. モニター<br>
#    (ここに記述）

# %% [markdown]
# #### 解答欄2-2
#
# - (ここに記述）
# - (ここに記述）

# %% [markdown]
# ## 3 「データサイエンス特論」の振り返り(10点)
# データサイエンス特論で学んだ各項目につき、以下の選択枝に応えて、振り返る。
#
# 選択結果と点数は連動しない、埋めれば10点を付与する。
# - どれだけ理解できたか
# - 役に立ちそうか
# - より学びたいか
